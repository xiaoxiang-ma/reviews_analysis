# %%
import pandas as pd
import numpy as np

# %%
import numpy as np
import pandas as pd
b_pandas = []
r_dtypes = {"stars": np.float16, 
            "useful": np.int32, 
            "funny": np.int32,
            "cool": np.int32,
           }
with open("../../yelp_reviews_dataset/yelp_academic_dataset_review.json", "r") as f:
    reader = pd.read_json(f, orient="records", lines=True, 
                          dtype=r_dtypes, chunksize=1000)
        
    for chunk in reader:
        reduced_chunk = chunk.drop(columns=['review_id', 'user_id'])\
                             .query("`date` >= '2019-12-01'")
        b_pandas.append(reduced_chunk)
    
b_pandas = pd.concat(b_pandas, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-9507d91e63da> in <module>
#      11                           dtype=r_dtypes, chunksize=1000)
#      12
# ---> 13     for chunk in reader:
#      14         reduced_chunk = chunk.drop(columns=['review_id', 'user_id'])\
#      15                              .query("`date` >= '2019-12-01'")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in __next__(self)
#     742         if lines:
#     743             lines_json = self._combine_lines(lines)
# --> 744             obj = self._get_object_parser(lines_json)
#     745
#     746             # Make sure that the returned objects have the right index.
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     714         obj = None
#     715         if typ == "frame":
# --> 716             obj = FrameParser(json, **kwargs).parse()
#     717
#     718         if typ == "series" or obj is None:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in parse(self)
#     834             return None
#     835         if self.convert_axes:
# --> 836             self._convert_axes()
#     837         self._try_convert_types()
#     838         return self.obj
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in _convert_axes(self)
#     855                 data=obj._get_axis(axis_name),
#     856                 use_dtypes=False,
# --> 857                 convert_dates=True,
#     858             )
#     859             if result:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in _try_convert_data(self, name, data, use_dtypes, convert_dates)
#     889
#     890         if convert_dates:
# --> 891             new_data, result = self._try_convert_to_date(data)
#     892             if result:
#     893                 return new_data, True
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in _try_convert_to_date(self, data)
#     970         for date_unit in date_units:
#     971             try:
# --> 972                 new_data = to_datetime(new_data, errors="raise", unit=date_unit)
#     973             except (ValueError, OverflowError, TypeError):
#     974                 continue
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     808         result = _assemble_from_unit_mappings(arg, errors, tz)
#     809     elif isinstance(arg, Index):
# --> 810         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     811         if not cache_array.empty:
#     812             result = _convert_and_box_cache(arg, cache_array, name=arg.name)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     167     from pandas import Series
#     168
# --> 169     cache_array = Series(dtype=object)
#     170
#     171     if cache:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     316                 data = data._mgr
#     317             elif is_dict_like(data):
# --> 318                 data, index = self._init_dict(data, index, dtype)
#     319                 dtype = None
#     320                 copy = False
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _init_dict(self, data, index, dtype)
#     410         # TODO: passing np.float64 to not break anything yet. See GH-17261
#     411         s = create_series_with_explicit_dtype(
# --> 412             values, index=keys, dtype=dtype, dtype_if_empty=np.float64
#     413         )
#     414
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/construction.py in create_series_with_explicit_dtype(data, index, dtype, name, copy, fastpath, dtype_if_empty)
#     665         dtype = dtype_if_empty
#     666     return Series(
# --> 667         data=data, index=index, dtype=dtype, name=name, copy=copy, fastpath=fastpath
#     668     )
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     362                     data = data.copy()
#     363             else:
# --> 364                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     365
#     366                 data = SingleBlockManager.from_array(data, index)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     494         subarr = construct_1d_arraylike_from_scalar(data, len(index), dtype)
#     495     else:
# --> 496         subarr = _try_cast(data, dtype, copy, raise_cast_failure)
#     497
#     498     # scalar like, GH
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/construction.py in _try_cast(arr, dtype, copy, raise_cast_failure)
#     596             and not (is_iterator(subarr) or isinstance(subarr, np.ndarray))
#     597         ):
# --> 598             subarr = construct_1d_object_array_from_listlike(subarr)
#     599         elif not is_extension_array_dtype(subarr):
#     600             subarr = construct_1d_ndarray_preserving_na(subarr, dtype, copy=copy)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in construct_1d_object_array_from_listlike(values)
#    1636     # making a 1D array that contains list-likes is a bit tricky:
#    1637     result = np.empty(len(values), dtype="object")
# -> 1638     result[:] = values
#    1639     return result
#    1640
#
# KeyboardInterrupt:

# %%
b_pandas
